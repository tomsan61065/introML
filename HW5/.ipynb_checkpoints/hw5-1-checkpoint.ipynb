# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from sklearn import linear_model

data = pd.read_csv("hw4_data.csv") #使用 pandas 的方式讀取 CSV
print(data)
data.head()

inputX = data[["Unnamed: 0"]].values.tolist() #將 dataframe 變成 list of lists
inputY = list(data["w1 = 4"])
#print(inputY)
#print(data["Unnamed: 0"])
#print(data["Unnamed: 0"].tolist())
#print(data["Unnamed: 0"].values)
# Out:
#     Unnamed: 0    w1 = 2    w1 = 4        w1 = 6    w0 = 0    w0 = 1    w0 = 2
# 0         -2.9  0.003018  0.000009  2.775080e-08  0.003018  0.001113  0.000410
# 1         -2.8  0.003684  0.000014  5.056530e-08  0.003684  0.001359  0.000500
# 2         -2.7  0.004496  0.000020  9.213600e-08  0.004496  0.001659  0.000611
# 3         -2.6  0.005486  0.000030  1.678830e-07  0.005486  0.002025  0.000746
# 4         -2.5  0.006693  0.000045  3.059020e-07  0.006693  0.002473  0.000911
# 5         -2.4  0.008163  0.000068  5.573900e-07  0.008163  0.003018  0.001113
# 6         -2.4  0.008163  0.000068  5.573900e-07  0.008163  0.003018  0.001113
# 7         -2.2  0.012128  0.000151  1.850600e-06  0.012128  0.004496  0.001659
# 8         -2.1  0.014774  0.000225  3.372000e-06  0.014774  0.005486  0.002025
# 9         -2.0  0.017986  0.000335  6.144170e-06  0.017986  0.006693  0.002473
# 10        -1.9  0.021881  0.000500  1.119540e-05  0.021881  0.008163  0.003018
# ...

# %%
# 選定所要使用的模型
logregr = LogisticRegression(C=1e5, solver='lbfgs', multi_class='multinomial')

# Train the model using the training sets
# 執行機器學習
logregr.fit(inputX, inputY1)

print('coefficient:' , logregr.coef_) #係數 A
print("intercept:", logregr.intercept_, end='\n') #截距 C
# Out:
# coefficient: [ 0.28857604 -0.19773506]
# intercept: 3.1470644520337894
# coefficient: [ 0.59672915 -0.48373119]
# intercept: 3.272726147504567

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(4, 3))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()
