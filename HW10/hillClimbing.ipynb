# %% [markdown]
# #### A simple gradient search for IntroML@cs.nccu.edu.tw
# #### prepared by Chao-Lin Liu

# %% [markdown]
# ##### $f(x) = 2x^2-7x+2$
# ##### $f(x) = x^4-2x^2+3x$
# ##### $f(x) = x^6+3x^5-2x^2+3x$

# %%
#func = lambda x: 2*x*x-7*x+2
#func = lambda x: x*x*x*x-2*x*x+3*x
func = lambda x:x**6 +3*x**5 -2*x**2+3*x

print(func(3))
# Out:
# 1449

# %%
# This is your first guess
guess = -2

# %%
# kicking off the search
step_size = 0.01

# %%
iter = 0
max_iter = 10000

# %%
while (iter < max_iter):
    prev = guess                         # save the previous guess
    guess1 = prev + step_size  # move to the next guess
    guess2 = prev - step_size
    if func(guess1) < func(guess2):
        attempt = guess1
    else:
        attempt = guess2
    if func(prev) > func(attempt):
        guess = attempt
    else:
        break
    iter = iter+1
    print("Iteration: ",iter,"\n current guess is: ", guess, "\n f(guess) is: ", func(guess))
    
print("The mininum is ",func(guess), " when the search stops at x = ", guess)
# Out:
# Iteration:  1
#  current guess is:  -2.01
#  f(guess) is:  -46.59015969909897
# Iteration:  2
#  current guess is:  -2.0199999999999996
#  f(guess) is:  -47.18047517113598
# Iteration:  3
#  current guess is:  -2.0299999999999994
#  f(guess) is:  -47.77069548057097
# Iteration:  4
#  current guess is:  -2.039999999999999
#  f(guess) is:  -48.36056227430396
# Iteration:  5
#  current guess is:  -2.049999999999999
#  f(guess) is:  -48.949809671874924
# Iteration:  6
#  current guess is:  -2.0599999999999987
#  f(guess) is:  -49.538164154943914
# Iteration:  7
#  current guess is:  -2.0699999999999985
#  f(guess) is:  -50.12534445605091
# Iteration:  8
#  current guess is:  -2.0799999999999983
#  f(guess) is:  -50.711061446655904
# Iteration:  9
#  current guess is:  -2.089999999999998
#  f(guess) is:  -51.295018024458884
# Iteration:  10
#  current guess is:  -2.099999999999998
#  f(guess) is:  -51.876908999999884
# Iteration:  11
#  current guess is:  -2.1099999999999977
#  f(guess) is:  -52.45642098253887
# Iteration:  12
#  current guess is:  -2.1199999999999974
#  f(guess) is:  -53.03323226521583
# Iteration:  13
#  current guess is:  -2.1299999999999972
#  f(guess) is:  -53.60701270949084
# Iteration:  14
#  current guess is:  -2.139999999999997
#  f(guess) is:  -54.17742362886382
# Iteration:  15
#  current guess is:  -2.149999999999997
#  f(guess) is:  -54.74411767187482
# Iteration:  16
#  current guess is:  -2.1599999999999966
#  f(guess) is:  -55.30673870438379
# Iteration:  17
#  current guess is:  -2.1699999999999964
#  f(guess) is:  -55.86492169113082
# Iteration:  18
#  current guess is:  -2.179999999999996
#  f(guess) is:  -56.41829257657581
# Iteration:  19
#  current guess is:  -2.189999999999996
#  f(guess) is:  -56.96646816501876
# Iteration:  20
#  current guess is:  -2.1999999999999957
#  f(guess) is:  -57.50905599999977
# Iteration:  21
#  current guess is:  -2.2099999999999955
#  f(guess) is:  -58.04565424297876
# Iteration:  22
#  current guess is:  -2.2199999999999953
#  f(guess) is:  -58.57585155129574
# Iteration:  23
#  current guess is:  -2.229999999999995
#  f(guess) is:  -59.09922695541075
# Iteration:  24
#  current guess is:  -2.239999999999995
#  f(guess) is:  -59.615349735423756
# Iteration:  25
#  current guess is:  -2.2499999999999947
#  f(guess) is:  -60.12377929687474
# Iteration:  26
#  current guess is:  -2.2599999999999945
#  f(guess) is:  -60.62406504582371
# Iteration:  27
#  current guess is:  -2.2699999999999942
#  f(guess) is:  -61.1157462632107
# Iteration:  28
#  current guess is:  -2.279999999999994
#  f(guess) is:  -61.59835197849571
# Iteration:  29
#  current guess is:  -2.289999999999994
#  f(guess) is:  -62.0714008425787
# Iteration:  30
#  current guess is:  -2.2999999999999936
#  f(guess) is:  -62.534400999999704
# Iteration:  31
#  current guess is:  -2.3099999999999934
#  f(guess) is:  -62.98684996041873
# Iteration:  32
#  current guess is:  -2.319999999999993
#  f(guess) is:  -63.42823446937568
# Iteration:  33
#  current guess is:  -2.329999999999993
#  f(guess) is:  -63.85803037833073
# Iteration:  34
#  current guess is:  -2.3399999999999928
#  f(guess) is:  -64.27570251398372
# Iteration:  35
#  current guess is:  -2.3499999999999925
#  f(guess) is:  -64.6807045468747
# Iteration:  36
#  current guess is:  -2.3599999999999923
#  f(guess) is:  -65.07247885926373
# Iteration:  37
#  current guess is:  -2.369999999999992
#  f(guess) is:  -65.45045641229069
# Iteration:  38
#  current guess is:  -2.379999999999992
#  f(guess) is:  -65.8140566124157
# Iteration:  39
#  current guess is:  -2.3899999999999917
#  f(guess) is:  -66.16268717713872
# Iteration:  40
#  current guess is:  -2.3999999999999915
#  f(guess) is:  -66.49574399999975
# Iteration:  41
#  current guess is:  -2.4099999999999913
#  f(guess) is:  -66.81261101485872
# Iteration:  42
#  current guess is:  -2.419999999999991
#  f(guess) is:  -67.11266005945578
# Iteration:  43
#  current guess is:  -2.429999999999991
#  f(guess) is:  -67.39525073825077
# Iteration:  44
#  current guess is:  -2.4399999999999906
#  f(guess) is:  -67.65973028454378
# Iteration:  45
#  current guess is:  -2.4499999999999904
#  f(guess) is:  -67.90543342187479
# Iteration:  46
#  current guess is:  -2.45999999999999
#  f(guess) is:  -68.13168222470378
# Iteration:  47
#  current guess is:  -2.46999999999999
#  f(guess) is:  -68.33778597837079
# Iteration:  48
#  current guess is:  -2.4799999999999898
#  f(guess) is:  -68.52304103833578
# Iteration:  49
#  current guess is:  -2.4899999999999896
#  f(guess) is:  -68.68673068869884
# Iteration:  50
#  current guess is:  -2.4999999999999893
#  f(guess) is:  -68.82812499999986
# Iteration:  51
#  current guess is:  -2.509999999999989
#  f(guess) is:  -68.94648068629888
# Iteration:  52
#  current guess is:  -2.519999999999989
#  f(guess) is:  -69.04104096153588
# Iteration:  53
#  current guess is:  -2.5299999999999887
#  f(guess) is:  -69.11103539517094
# Iteration:  54
#  current guess is:  -2.5399999999999885
#  f(guess) is:  -69.15567976710393
# Iteration:  55
#  current guess is:  -2.5499999999999883
#  f(guess) is:  -69.174175921875
# The mininum is  -69.174175921875  when the search stops at x =  -2.5499999999999883
